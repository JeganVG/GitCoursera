# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# >Jegan.V.G
#
# >Pursuing B.Tech in Mepco Schlenk Engineering College, Sivakasi

# %% [markdown]
# * I am interested in data science because the field is very interesting and developing. I used to love tracing back cases with evidences and this is exactly what I need .

# %% [markdown]
# ### The code in cell 5 will display the subtraction of two numbers

# %%
12 - 11
# Out:
# 1

# %% [markdown]
# ### unordered list
# - one
# - two
# - three
#
# ### ordered list
# 1. one
# 2. two
# 3. three
#
# ### table
# <table>
# <tr>
# <td>1000</td>
# <td>2000</td>
# <td>5000</td>
# </tr>
# </table>
